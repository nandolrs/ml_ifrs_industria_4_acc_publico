# %%
import requests

# The URL you want to make a GET request to
url = "https://apisidra.ibge.gov.br/values/t/4678/n3/all/v/9819/p/2022/d/v9819%201" 

# Make the GET request
response = requests.get(url)
