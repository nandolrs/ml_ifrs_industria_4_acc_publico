# %% [raw]
# 1. variáveis
# 1.1 taxa de subocupação
# 1.2 ano de ocupação = 2022
# 1.3 unidade territorial = unidade da federação

# %%
import pandas as pd

# The URL you want to make a GET request to
url4678 = "https://apisidra.ibge.gov.br/values/t/4678/n3/all/v/9819/p/2022/d/v9819%201" 
X_full4678 = pd.read_json(url4678) 

X_titulos = X_full4678.iloc[0]

X_data = X_full4678.copy(deep=True)

X_data = X_data.drop(columns=['MC','MN','D1C','D2C','D2N','NC','NN','D3C','D3N'])

X_data = X_data.drop(0, axis=0) 
X_data
# Out:
#        V                  D1N
# 1    2.9             Rondônia
# 2    4.2                 Acre
# 3    5.4             Amazonas
# 4    2.2              Roraima
# 5    9.2                 Pará
# 6    5.8                Amapá
# 7    4.8            Tocantins
# 8    8.9             Maranhão
# 9   21.3                Piauí
# 10   9.3                Ceará
# 11   9.1  Rio Grande do Norte
# 12  10.1              Paraíba
# 13  10.5           Pernambuco
# 14   9.7              Alagoas
# 15  15.2              Sergipe
# 16  12.8                Bahia
# 17   5.6         Minas Gerais
# 18   4.0       Espírito Santo
# 19   4.8       Rio de Janeiro
# 20   5.1            São Paulo
# 21   3.8               Paraná
# 22   1.6       Santa Catarina
# 23   4.4    Rio Grande do Sul
# 24   3.6   Mato Grosso do Sul
# 25   2.9          Mato Grosso
# 26   3.7                Goiás
# 27   6.7     Distrito Federal

# %% [markdown]
# Deixa apenas dados (retira os titulos)

# %% [raw]
# Deixa apenas as colunas necessárias.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10*0.6, 5*0.95), layout='constrained')
plt.xticks(rotation=90)

X_data_categorias = X_data['D1N']
X_data_valores = X_data['V']

ax.bar(X_data_categorias, X_data_valores, align='edge')
# Out:
# <BarContainer object of 27 artists>
